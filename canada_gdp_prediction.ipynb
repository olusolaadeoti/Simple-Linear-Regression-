# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model

df = pd.read_csv('canada_gdp.csv')

plt.scatter(df.Year,df.GDP)
plt.plot(df.Year,df.GDP, color="r")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Year']],df.GDP)
reg.predict([[2020]])
# Out:
# /Users/macbookpro/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([48535.89549971])
